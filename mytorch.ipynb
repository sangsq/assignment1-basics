# %%
from torch.nn import Module, ModuleList
from torch.optim import Optimizer
import torch as t

# %%
a = t.randn(10,5)
b = t.tensor([[1,2,3], [1,2,3]])
# a[b, :].shape
a[b, ...].shape
# Out:
# torch.Size([2, 3, 5])

# %%
a.unsqueeze(-1).squeeze(-1).shape
# Out:
# torch.Size([10, 5])
