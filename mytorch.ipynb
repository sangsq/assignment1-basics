# %%
from torch.nn import Module, ModuleList
from torch.optim import Optimizer
import torch as t

# %%
class Linear(Module):
    def __init__(self,)
# Out:
#   Cell In[2], line 2
#     def __init__(self,)
#                        ^
# SyntaxError: expected ':'

# %%
t.nn.Linear
